# %%
import numpy as np
import sys
sys.path.append(r"C:\Users\alasm\Masteroppgave\w3tp")
import w3t as w3t
import os
import matplotlib.pyplot as plt
from numpy.polynomial.polynomial import Polynomial

# %%
# Define the path where arrays are stored
file_path = r"C:\Users\alasm\OneDrive - NTNU\Dokumenter\NTNU\5. klasse\Masteroppgave_lokal\Python code ny\Arrays_Static_coeff"

# Dictionary to store loaded arrays
arrays_loaded = {}

# List of array names
array_names = [
    #Unfiltered
    "cd_single_high", "cd_alpha_single_high",

    "cd_1D_mus_high_upwind_deck", "cd_alpha_1D_mus_high",
    "cd_2D_mus_high_upwind_deck","cd_alpha_2D_mus_high",
    "cd_3D_mus_high_upwind_deck", "cd_alpha_3D_mus_high",
    "cd_4D_mus_high_upwind_deck", "cd_alpha_4D_mus_high",
    "cd_5D_mus_high_upwind_deck", "cd_alpha_5D_mus_high",

    "cd_1D_mds_high_upwind_deck", "cd_alpha_1D_mds_high",
    "cd_2D_mds_high_upwind_deck", "cd_alpha_2D_mds_high",
    "cd_3D_mds_high_upwind_deck", "cd_alpha_3D_mds_high",
    "cd_4D_mds_high_upwind_deck", "cd_alpha_4D_mds_high",
    "cd_5D_mds_high_upwind_deck", "cd_alpha_5D_mds_high",

    "cd_1D_mus_high_downwind_deck", "cd_alpha_1D_mus_high",
    "cd_2D_mus_high_downwind_deck", "cd_alpha_2D_mus_high",
    "cd_3D_mus_high_downwind_deck", "cd_alpha_3D_mus_high",
    "cd_4D_mus_high_downwind_deck", "cd_alpha_4D_mus_high",
    "cd_5D_mus_high_downwind_deck", "cd_alpha_5D_mus_high",

    "cd_1D_mds_high_downwind_deck", "cd_alpha_1D_mds_high",
    "cd_2D_mds_high_downwind_deck", "cd_alpha_2D_mds_high",
    "cd_3D_mds_high_downwind_deck", "cd_alpha_3D_mds_high",
    "cd_4D_mds_high_downwind_deck", "cd_alpha_4D_mds_high",
    "cd_5D_mds_high_downwind_deck", "cd_alpha_5D_mds_high",

    #Filtered
    "cd_single_high_filtered", "cd_alpha_single_high_filtered",

    "cd_1D_mus_high_upwind_deck_filtered", "cd_alpha_1D_mus_high_filtered",
    "cd_2D_mus_high_upwind_deck_filtered","cd_alpha_2D_mus_high_filtered",
    "cd_3D_mus_high_upwind_deck_filtered", "cd_alpha_3D_mus_high_filtered",
    "cd_4D_mus_high_upwind_deck_filtered", "cd_alpha_4D_mus_high_filtered",

    "cd_1D_mds_high_upwind_deck_filtered", "cd_alpha_1D_mds_high_filtered",
 
    "cd_1D_mus_high_downwind_deck_filtered", "cd_alpha_1D_mus_high_filtered",
    "cd_2D_mus_high_downwind_deck_filtered", "cd_alpha_2D_mus_high_filtered",
    "cd_3D_mus_high_downwind_deck_filtered", "cd_alpha_3D_mus_high_filtered",
    "cd_4D_mus_high_downwind_deck_filtered", "cd_alpha_4D_mus_high_filtered",

    "cd_1D_mds_high_downwind_deck_filtered", "cd_alpha_1D_mds_high_filtered"]


# Load each .npy file
for name in array_names:
    arrays_loaded[name] = np.load(os.path.join(file_path, f"{name}.npy"))

# %%
#Unfiltered
cd_single_high = arrays_loaded["cd_single_high"]
cd_alpha_single_high = arrays_loaded["cd_alpha_single_high"]


cd_1D_mus_high_upwind_deck = arrays_loaded["cd_1D_mus_high_upwind_deck"]
cd_alpha_1D_mus_high = arrays_loaded["cd_alpha_1D_mus_high"]

cd_2D_mus_high_upwind_deck = arrays_loaded["cd_2D_mus_high_upwind_deck"]
cd_alpha_2D_mus_high = arrays_loaded["cd_alpha_2D_mus_high"]

cd_3D_mus_high_upwind_deck = arrays_loaded["cd_3D_mus_high_upwind_deck"]
cd_alpha_3D_mus_high = arrays_loaded["cd_alpha_3D_mus_high"]

cd_4D_mus_high_upwind_deck = arrays_loaded["cd_4D_mus_high_upwind_deck"]
cd_alpha_4D_mus_high = arrays_loaded["cd_alpha_4D_mus_high"]

cd_5D_mus_high_upwind_deck = arrays_loaded["cd_5D_mus_high_upwind_deck"]
cd_alpha_5D_mus_high = arrays_loaded["cd_alpha_5D_mus_high"]


cd_1D_mds_high_upwind_deck = arrays_loaded["cd_1D_mds_high_upwind_deck"]
cd_alpha_1D_mds_high = arrays_loaded["cd_alpha_1D_mds_high"]

cd_2D_mds_high_upwind_deck = arrays_loaded["cd_2D_mds_high_upwind_deck"]
cd_alpha_2D_mds_high = arrays_loaded["cd_alpha_2D_mds_high"]

cd_3D_mds_high_upwind_deck = arrays_loaded["cd_3D_mds_high_upwind_deck"]
cd_alpha_3D_mds_high = arrays_loaded["cd_alpha_3D_mds_high"]

cd_4D_mds_high_upwind_deck = arrays_loaded["cd_4D_mds_high_upwind_deck"]
cd_alpha_4D_mds_high = arrays_loaded["cd_alpha_4D_mds_high"]

cd_5D_mds_high_upwind_deck = arrays_loaded["cd_5D_mds_high_upwind_deck"]
cd_alpha_5D_mds_high = arrays_loaded["cd_alpha_5D_mds_high"]


cd_1D_mus_high_downwind_deck = arrays_loaded["cd_1D_mus_high_downwind_deck"]
cd_alpha_1D_mus_high = arrays_loaded["cd_alpha_1D_mus_high"]

cd_2D_mus_high_downwind_deck = arrays_loaded["cd_2D_mus_high_downwind_deck"]
cd_alpha_2D_mus_high = arrays_loaded["cd_alpha_2D_mus_high"]

cd_3D_mus_high_downwind_deck = arrays_loaded["cd_3D_mus_high_downwind_deck"]
cd_alpha_3D_mus_high = arrays_loaded["cd_alpha_3D_mus_high"]

cd_4D_mus_high_downwind_deck = arrays_loaded["cd_4D_mus_high_downwind_deck"]
cd_alpha_4D_mus_high = arrays_loaded["cd_alpha_4D_mus_high"]

cd_5D_mus_high_downwind_deck = arrays_loaded["cd_5D_mus_high_downwind_deck"]
cd_alpha_5D_mus_high = arrays_loaded["cd_alpha_5D_mus_high"]


cd_1D_mds_high_downwind_deck = arrays_loaded["cd_1D_mds_high_downwind_deck"]
cd_alpha_1D_mds_high = arrays_loaded["cd_alpha_1D_mds_high"]

cd_2D_mds_high_downwind_deck = arrays_loaded["cd_2D_mds_high_downwind_deck"]
cd_alpha_2D_mds_high = arrays_loaded["cd_alpha_2D_mds_high"]

cd_3D_mds_high_downwind_deck = arrays_loaded["cd_3D_mds_high_downwind_deck"]
cd_alpha_3D_mds_high = arrays_loaded["cd_alpha_3D_mds_high"]

cd_4D_mds_high_downwind_deck = arrays_loaded["cd_4D_mds_high_downwind_deck"]
cd_alpha_4D_mds_high = arrays_loaded["cd_alpha_4D_mds_high"]

cd_5D_mds_high_downwind_deck = arrays_loaded["cd_5D_mds_high_downwind_deck"]
cd_alpha_5D_mds_high = arrays_loaded["cd_alpha_5D_mds_high"]

#Filtered
cd_single_high_filtered = arrays_loaded["cd_single_high_filtered"]
cd_alpha_single_high_filtered = arrays_loaded["cd_alpha_single_high_filtered"]


cd_1D_mus_high_upwind_deck_filtered = arrays_loaded["cd_1D_mus_high_upwind_deck_filtered"]
cd_alpha_1D_mus_high_filtered = arrays_loaded["cd_alpha_1D_mus_high_filtered"]

cd_2D_mus_high_upwind_deck_filtered = arrays_loaded["cd_2D_mus_high_upwind_deck_filtered"]
cd_alpha_2D_mus_high_filtered = arrays_loaded["cd_alpha_2D_mus_high_filtered"]

cd_3D_mus_high_upwind_deck_filtered = arrays_loaded["cd_3D_mus_high_upwind_deck_filtered"]
cd_alpha_3D_mus_high_filtered = arrays_loaded["cd_alpha_3D_mus_high_filtered"]

cd_4D_mus_high_upwind_deck_filtered = arrays_loaded["cd_4D_mus_high_upwind_deck_filtered"]
cd_alpha_4D_mus_high_filtered = arrays_loaded["cd_alpha_4D_mus_high_filtered"]


cd_1D_mds_high_upwind_deck_filtered = arrays_loaded["cd_1D_mds_high_upwind_deck_filtered"]
cd_alpha_1D_mds_high_filtered = arrays_loaded["cd_alpha_1D_mds_high_filtered"]

cd_1D_mus_high_downwind_deck_filtered = arrays_loaded["cd_1D_mus_high_downwind_deck_filtered"]
cd_alpha_1D_mus_high_filtered = arrays_loaded["cd_alpha_1D_mus_high_filtered"]

cd_2D_mus_high_downwind_deck_filtered = arrays_loaded["cd_2D_mus_high_downwind_deck_filtered"]
cd_alpha_2D_mus_high_filtered = arrays_loaded["cd_alpha_2D_mus_high_filtered"]

cd_3D_mus_high_downwind_deck_filtered = arrays_loaded["cd_3D_mus_high_downwind_deck_filtered"]
cd_alpha_3D_mus_high_filtered = arrays_loaded["cd_alpha_3D_mus_high_filtered"]

cd_4D_mus_high_downwind_deck_filtered = arrays_loaded["cd_4D_mus_high_downwind_deck_filtered"]
cd_alpha_4D_mus_high_filtered = arrays_loaded["cd_alpha_4D_mus_high_filtered"]


cd_1D_mds_high_downwind_deck_filtered = arrays_loaded["cd_1D_mds_high_downwind_deck_filtered"]
cd_alpha_1D_mds_high_filtered = arrays_loaded["cd_alpha_1D_mds_high_filtered"]

# %%
def fix(filtered, unfiltered):
    """
    Replace NaNs and their immediate neighbors in a filtered array with values from an unfiltered array.

    Parameters:
    - filtered: The array containing NaN values.
    - unfiltered: The original array with all valid values.

    Returns:
    - A new array where NaNs and their neighbors are replaced with values from the unfiltered array.
    """
    if filtered.shape != unfiltered.shape:
        raise ValueError("Filtered and unfiltered arrays must have the same shape.")

    result = filtered.copy()
    nan_indices = np.where(np.isnan(filtered))[0]
    indices_to_replace = set()

    for idx in nan_indices:
        indices_to_replace.add(idx)
        if idx > 0:
            indices_to_replace.add(idx - 1)
        if idx < len(filtered) - 1:
            indices_to_replace.add(idx + 1)

    for idx in indices_to_replace:
        result[idx] = unfiltered[idx]

    return result

# %%
def poly_fit(x_MDS, x_MUS, y_MDS, y_MUS, plot_1=True, plot_2=True, name=None):
    mask_MDS = (x_MDS >= -4) & (x_MDS <= 4)
    mask_MUS = (x_MUS >= -4) & (x_MUS <= 4)
    
    X_MDS = x_MDS[mask_MDS]
    Y_MDS = y_MDS[mask_MDS]

    X_MUS = x_MUS[mask_MUS]
    Y_MUS = y_MUS[mask_MUS]

    deg = 3
    p_MDS = Polynomial.fit(X_MDS, Y_MDS, deg).convert()
    p_MUS = Polynomial.fit(X_MUS, Y_MUS, deg).convert()

    derivative_MDS = p_MDS.deriv()
    derivative_MUS = p_MUS.deriv()

    Y_MDS_fit = p_MDS(X_MDS)
    Y_MUS_fit = p_MUS(X_MUS)

    average = (p_MDS(0) + p_MUS(0))/2
    
    Y_MDS_average = Y_MDS - p_MDS(0) + average
    Y_MUS_average = Y_MUS - p_MUS(0) + average

    Y_MDS_fit_average = Y_MDS_fit - p_MDS(0) + average
    Y_MUS_fit_average = Y_MUS_fit - p_MUS(0) + average

    if plot_1 == True:
        plt.figure(figsize=(10, 6))
        plt.plot(X_MDS, Y_MDS, label='MDS', color='blue')
        plt.plot(X_MUS, Y_MUS, label='MUS', color='red')
        plt.plot(X_MDS, Y_MDS_fit, label='MDS Fit', linestyle='--', color='blue')
        plt.plot(X_MUS, Y_MUS_fit, label='MUS Fit', linestyle='--', color='red')
        plt.xlabel(r'$\alpha$')
        plt.ylabel(r'$C_D$')
        plt.title(name)
        plt.legend()
        plt.grid()
        plt.show()

    if plot_2 == True:
        plt.figure(figsize=(10, 6))
        plt.plot(X_MDS, Y_MDS_average, label='MDS', color='blue')
        plt.plot(X_MUS, Y_MUS_average, label='MUS', color='red')
        plt.plot(X_MDS, Y_MDS_fit_average, label='MDS Fit', linestyle='--', color='blue')
        plt.plot(X_MUS, Y_MUS_fit_average, label='MUS Fit', linestyle='--', color='red')
        plt.xlabel(r'$\alpha$')
        plt.ylabel(r'$C_D$')
        plt.title(name + ' - Average')
        plt.legend()
        plt.grid()
        plt.show()

    

    return average, derivative_MDS(0), derivative_MUS(0)

# %%
def CD(x_MDS, MDS_unfiltered, x_MUS, MUS_unfiltered, MDS_filtered = 0, MUS_filtered = 0, name = ''):
    if np.all(MDS_filtered == 0):
        y_MDS = MDS_unfiltered
    else:
        y_MDS = fix(MDS_filtered, MDS_unfiltered)

    if np.all(MUS_filtered == 0):
        y_MUS = MUS_unfiltered
    else:
        y_MUS = fix(MUS_filtered, MUS_unfiltered)

    CD_mean, CD_d_MUS, CD_d_MDS = poly_fit(x_MDS, x_MUS, y_MDS, y_MUS, plot_1=True, plot_2=True, name=name)

    filename = name + '.npy'
    save_dir = 'Static_coeff_for_buffeting'

    save_path = os.path.join(save_dir, filename)

    os.makedirs(save_dir, exist_ok=True)

    np.save(save_path, np.array([CD_mean, CD_d_MUS, CD_d_MDS]))

    print(f"Numpy array saved to {save_path}")

    print(CD_mean, CD_d_MUS, CD_d_MDS)

# %%
CD(cd_alpha_1D_mds_high, cd_1D_mds_high_upwind_deck,  cd_alpha_1D_mus_high, cd_1D_mus_high_upwind_deck, cd_1D_mds_high_upwind_deck_filtered, cd_1D_mus_high_upwind_deck_filtered, name = 'CD_Upwind_1D')
CD(cd_alpha_1D_mds_high, cd_1D_mds_high_downwind_deck,  cd_alpha_1D_mus_high, cd_1D_mus_high_downwind_deck, cd_1D_mds_high_downwind_deck_filtered, cd_1D_mus_high_downwind_deck_filtered, name = 'CD_Downwind_1D')
CD(cd_alpha_2D_mds_high, cd_2D_mds_high_upwind_deck,  cd_alpha_2D_mus_high, cd_2D_mus_high_upwind_deck, MDS_filtered = 0, MUS_filtered = cd_2D_mus_high_upwind_deck_filtered, name = 'CD_Upwind_2D')
CD(cd_alpha_2D_mds_high, cd_2D_mds_high_downwind_deck,  cd_alpha_2D_mus_high, cd_2D_mus_high_downwind_deck, MDS_filtered = 0, MUS_filtered = cd_2D_mus_high_downwind_deck_filtered, name = 'CD_Downwind_2D')
CD(cd_alpha_3D_mds_high, cd_3D_mds_high_upwind_deck,  cd_alpha_3D_mus_high, cd_3D_mus_high_upwind_deck, MDS_filtered = 0, MUS_filtered = cd_3D_mus_high_upwind_deck_filtered, name = 'CD_Upwind_3D')
CD(cd_alpha_3D_mds_high, cd_3D_mds_high_downwind_deck,  cd_alpha_3D_mus_high, cd_3D_mus_high_downwind_deck, MDS_filtered = 0, MUS_filtered = cd_3D_mus_high_downwind_deck_filtered, name = 'CD_Downwind_3D')
CD(cd_alpha_4D_mds_high, cd_4D_mds_high_upwind_deck,  cd_alpha_4D_mus_high, cd_4D_mus_high_upwind_deck, MDS_filtered = 0, MUS_filtered = cd_4D_mus_high_upwind_deck_filtered, name = 'CD_Upwind_4D')
CD(cd_alpha_4D_mds_high, cd_4D_mds_high_downwind_deck,  cd_alpha_4D_mus_high, cd_4D_mus_high_downwind_deck, MDS_filtered = 0, MUS_filtered = cd_4D_mus_high_downwind_deck_filtered, name = 'CD_Downwind_4D')
CD(cd_alpha_5D_mds_high, cd_5D_mds_high_upwind_deck,  cd_alpha_5D_mus_high, cd_5D_mus_high_upwind_deck, MDS_filtered = 0, MUS_filtered = 0, name = 'CD_Upwind_5D')
CD(cd_alpha_5D_mds_high, cd_5D_mds_high_downwind_deck,  cd_alpha_5D_mus_high, cd_5D_mus_high_downwind_deck, MDS_filtered = 0, MUS_filtered = 0, name = 'CD_Downwind_5D')
# Out:
# Numpy array saved to Static_coeff_for_buffeting\CD_Upwind_1D.npy
# 0.36456887968413276 -0.001983246343106694 0.004891811850074886
# Numpy array saved to Static_coeff_for_buffeting\CD_Downwind_1D.npy
# 0.34082462494012566 -0.00794654036257286 0.0035460687211256326
# Numpy array saved to Static_coeff_for_buffeting\CD_Upwind_2D.npy
# 0.39521060330042246 -0.0023660900582895953 -0.001699169673484696
# Numpy array saved to Static_coeff_for_buffeting\CD_Downwind_2D.npy
# 0.4166087450458281 -0.00856813822018018 -0.005108234234460286
# Numpy array saved to Static_coeff_for_buffeting\CD_Upwind_3D.npy
# 0.43422598101649956 -0.0025262793870351394 -0.009320046056882038
# Numpy array saved to Static_coeff_for_buffeting\CD_Downwind_3D.npy
# 0.42439147338127703 -0.009183177458867382 0.001145895312145607
# Numpy array saved to Static_coeff_for_buffeting\CD_Upwind_4D.npy
# 0.46942546706264 -0.0012855632468793186 -0.007924868962192015
# ...
