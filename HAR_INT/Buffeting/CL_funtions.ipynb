# %%
import numpy as np
import sys
sys.path.append(r"C:\Users\alasm\Masteroppgave\w3tp")
import w3t as w3t
import os
import matplotlib.pyplot as plt
from numpy.polynomial.polynomial import Polynomial

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.serif": ["Verdana"],
    "mathtext.fontset": "cm",
    "font.size": 14,             # Base font size
    "axes.titlesize": 16,        # Title font size
    "axes.labelsize": 14,        # Axis label size
    "xtick.labelsize": 12,       # X tick label size
    "ytick.labelsize": 12,       # Y tick label size
})

# %%
# Define the path where arrays are stored
file_path = r"C:\Users\alasm\OneDrive - NTNU\Dokumenter\NTNU\5. klasse\Masteroppgave_lokal\Python code ny\Arrays_Static_coeff"

# Dictionary to store loaded arrays
arrays_loaded = {}

# List of array names
array_names = [
    #Unfiltered
    "cl_single_high", "cl_alpha_single_high",

    "cl_1D_mus_high_upwind_deck", "cl_alpha_1D_mus_high",
    "cl_2D_mus_high_upwind_deck", "cl_alpha_2D_mus_high",
    "cl_3D_mus_high_upwind_deck", "cl_alpha_3D_mus_high",
    "cl_4D_mus_high_upwind_deck", "cl_alpha_4D_mus_high",
    "cl_5D_mus_high_upwind_deck", "cl_alpha_5D_mus_high",

    "cl_1D_mds_high_upwind_deck", "cl_alpha_1D_mds_high",
    "cl_2D_mds_high_upwind_deck", "cl_alpha_2D_mds_high",
    "cl_3D_mds_high_upwind_deck", "cl_alpha_3D_mds_high",
    "cl_4D_mds_high_upwind_deck", "cl_alpha_4D_mds_high",
    "cl_5D_mds_high_upwind_deck", "cl_alpha_5D_mds_high",

    "cl_1D_mus_high_downwind_deck", "cl_alpha_1D_mus_high",
    "cl_2D_mus_high_downwind_deck", "cl_alpha_2D_mus_high",
    "cl_3D_mus_high_downwind_deck", "cl_alpha_3D_mus_high",
    "cl_4D_mus_high_downwind_deck", "cl_alpha_4D_mus_high",
    "cl_5D_mus_high_downwind_deck", "cl_alpha_5D_mus_high",

    "cl_1D_mds_high_downwind_deck", "cl_alpha_1D_mds_high",
    "cl_2D_mds_high_downwind_deck", "cl_alpha_2D_mds_high",
    "cl_3D_mds_high_downwind_deck", "cl_alpha_3D_mds_high",
    "cl_4D_mds_high_downwind_deck", "cl_alpha_4D_mds_high",
    "cl_5D_mds_high_downwind_deck", "cl_alpha_5D_mds_high",

    #Filtered
    "cl_single_high_filtered", "cl_alpha_single_high_filtered",

    "cl_1D_mus_high_upwind_deck_filtered", "cl_alpha_1D_mus_high_filtered",
    "cl_2D_mus_high_upwind_deck_filtered", "cl_alpha_2D_mus_high_filtered",
    "cl_3D_mus_high_upwind_deck_filtered", "cl_alpha_3D_mus_high_filtered",
    "cl_4D_mus_high_upwind_deck_filtered", "cl_alpha_4D_mus_high_filtered",
    "cl_5D_mus_high_upwind_deck_filtered", "cl_alpha_5D_mus_high_filtered",

    "cl_1D_mds_high_upwind_deck_filtered", "cl_alpha_1D_mds_high_filtered",

    "cl_1D_mus_high_downwind_deck_filtered", "cl_alpha_1D_mus_high_filtered",
    "cl_2D_mus_high_downwind_deck_filtered", "cl_alpha_2D_mus_high_filtered",
    "cl_3D_mus_high_downwind_deck_filtered", "cl_alpha_3D_mus_high_filtered",
    "cl_4D_mus_high_downwind_deck_filtered", "cl_alpha_4D_mus_high_filtered",
    "cl_5D_mus_high_downwind_deck_filtered", "cl_alpha_5D_mus_high_filtered",

    "cl_1D_mds_high_downwind_deck_filtered", "cl_alpha_1D_mds_high_filtered"]


# Load each .npy file
for name in array_names:
    arrays_loaded[name] = np.load(os.path.join(file_path, f"{name}.npy"))

# %%
#Unfiltered
cl_single_high = arrays_loaded["cl_single_high"]
cl_alpha_single_high = arrays_loaded["cl_alpha_single_high"]


cl_1D_mus_high_upwind_deck = arrays_loaded["cl_1D_mus_high_upwind_deck"]
cl_alpha_1D_mus_high = arrays_loaded["cl_alpha_1D_mus_high"]

cl_2D_mus_high_upwind_deck = arrays_loaded["cl_2D_mus_high_upwind_deck"]
cl_alpha_2D_mus_high = arrays_loaded["cl_alpha_2D_mus_high"]

cl_3D_mus_high_upwind_deck = arrays_loaded["cl_3D_mus_high_upwind_deck"]
cl_alpha_3D_mus_high = arrays_loaded["cl_alpha_3D_mus_high"]

cl_4D_mus_high_upwind_deck = arrays_loaded["cl_4D_mus_high_upwind_deck"]
cl_alpha_4D_mus_high = arrays_loaded["cl_alpha_4D_mus_high"]

cl_5D_mus_high_upwind_deck = arrays_loaded["cl_5D_mus_high_upwind_deck"]
cl_alpha_5D_mus_high = arrays_loaded["cl_alpha_5D_mus_high"]


cl_1D_mds_high_upwind_deck = arrays_loaded["cl_1D_mds_high_upwind_deck"]
cl_alpha_1D_mds_high = arrays_loaded["cl_alpha_1D_mds_high"]

cl_2D_mds_high_upwind_deck = arrays_loaded["cl_2D_mds_high_upwind_deck"]
cl_alpha_2D_mds_high = arrays_loaded["cl_alpha_2D_mds_high"]

cl_3D_mds_high_upwind_deck = arrays_loaded["cl_3D_mds_high_upwind_deck"]
cl_alpha_3D_mds_high = arrays_loaded["cl_alpha_3D_mds_high"]

cl_4D_mds_high_upwind_deck = arrays_loaded["cl_4D_mds_high_upwind_deck"]
cl_alpha_4D_mds_high = arrays_loaded["cl_alpha_4D_mds_high"]

cl_5D_mds_high_upwind_deck = arrays_loaded["cl_5D_mds_high_upwind_deck"]
cl_alpha_5D_mds_high = arrays_loaded["cl_alpha_5D_mds_high"]


cl_1D_mus_high_downwind_deck = arrays_loaded["cl_1D_mus_high_downwind_deck"]
cl_alpha_1D_mus_high = arrays_loaded["cl_alpha_1D_mus_high"]

cl_2D_mus_high_downwind_deck = arrays_loaded["cl_2D_mus_high_downwind_deck"]
cl_alpha_2D_mus_high = arrays_loaded["cl_alpha_2D_mus_high"]

cl_3D_mus_high_downwind_deck = arrays_loaded["cl_3D_mus_high_downwind_deck"]
cl_alpha_3D_mus_high = arrays_loaded["cl_alpha_3D_mus_high"]

cl_4D_mus_high_downwind_deck = arrays_loaded["cl_4D_mus_high_downwind_deck"]
cl_alpha_4D_mus_high = arrays_loaded["cl_alpha_4D_mus_high"]

cl_5D_mus_high_downwind_deck = arrays_loaded["cl_5D_mus_high_downwind_deck"]
cl_alpha_5D_mus_high = arrays_loaded["cl_alpha_5D_mus_high"]


cl_1D_mds_high_downwind_deck = arrays_loaded["cl_1D_mds_high_downwind_deck"]
cl_alpha_1D_mds_high = arrays_loaded["cl_alpha_1D_mds_high"]

cl_2D_mds_high_downwind_deck = arrays_loaded["cl_2D_mds_high_downwind_deck"]
cl_alpha_2D_mds_high = arrays_loaded["cl_alpha_2D_mds_high"]

cl_3D_mds_high_downwind_deck = arrays_loaded["cl_3D_mds_high_downwind_deck"]
cl_alpha_3D_mds_high = arrays_loaded["cl_alpha_3D_mds_high"]

cl_4D_mds_high_downwind_deck = arrays_loaded["cl_4D_mds_high_downwind_deck"]
cl_alpha_4D_mds_high = arrays_loaded["cl_alpha_4D_mds_high"]

cl_5D_mds_high_downwind_deck = arrays_loaded["cl_5D_mds_high_downwind_deck"]
cl_alpha_5D_mds_high = arrays_loaded["cl_alpha_5D_mds_high"]

#Filtered
cl_single_high_filtered = arrays_loaded["cl_single_high_filtered"]
cl_alpha_single_high_filtered = arrays_loaded["cl_alpha_single_high_filtered"]


cl_1D_mus_high_upwind_deck_filtered = arrays_loaded["cl_1D_mus_high_upwind_deck_filtered"]
cl_alpha_1D_mus_high_filtered = arrays_loaded["cl_alpha_1D_mus_high_filtered"]

cl_2D_mus_high_upwind_deck_filtered = arrays_loaded["cl_2D_mus_high_upwind_deck_filtered"]
cl_alpha_2D_mus_high_filtered = arrays_loaded["cl_alpha_2D_mus_high_filtered"]

cl_3D_mus_high_upwind_deck_filtered = arrays_loaded["cl_3D_mus_high_upwind_deck_filtered"]
cl_alpha_3D_mus_high_filtered = arrays_loaded["cl_alpha_3D_mus_high_filtered"]

cl_4D_mus_high_upwind_deck_filtered = arrays_loaded["cl_4D_mus_high_upwind_deck_filtered"]
cl_alpha_4D_mus_high_filtered = arrays_loaded["cl_alpha_4D_mus_high_filtered"]

cl_5D_mus_high_upwind_deck_filtered = arrays_loaded["cl_5D_mus_high_upwind_deck_filtered"]
cl_alpha_5D_mus_high_filtered = arrays_loaded["cl_alpha_5D_mus_high_filtered"]


cl_1D_mds_high_upwind_deck_filtered = arrays_loaded["cl_1D_mds_high_upwind_deck_filtered"]
cl_alpha_1D_mds_high_filtered = arrays_loaded["cl_alpha_1D_mds_high_filtered"]


cl_1D_mus_high_downwind_deck_filtered = arrays_loaded["cl_1D_mus_high_downwind_deck_filtered"]
cl_alpha_1D_mus_high_filtered = arrays_loaded["cl_alpha_1D_mus_high_filtered"]

cl_2D_mus_high_downwind_deck_filtered = arrays_loaded["cl_2D_mus_high_downwind_deck_filtered"]
cl_alpha_2D_mus_high_filtered = arrays_loaded["cl_alpha_2D_mus_high_filtered"]

cl_3D_mus_high_downwind_deck_filtered = arrays_loaded["cl_3D_mus_high_downwind_deck_filtered"]
cl_alpha_3D_mus_high_filtered = arrays_loaded["cl_alpha_3D_mus_high_filtered"]

cl_4D_mus_high_downwind_deck_filtered = arrays_loaded["cl_4D_mus_high_downwind_deck_filtered"]
cl_alpha_4D_mus_high_filtered = arrays_loaded["cl_alpha_4D_mus_high_filtered"]

cl_5D_mus_high_downwind_deck_filtered = arrays_loaded["cl_5D_mus_high_downwind_deck_filtered"]
cl_alpha_5D_mus_high_filtered = arrays_loaded["cl_alpha_5D_mus_high_filtered"]


cl_1D_mds_high_downwind_deck_filtered = arrays_loaded["cl_1D_mds_high_downwind_deck_filtered"]
cl_alpha_1D_mds_high_filtered = arrays_loaded["cl_alpha_1D_mds_high_filtered"]

# %%
def fix(filtered, unfiltered):
    """
    Replace NaNs and their immediate neighbors in a filtered array with values from an unfiltered array.

    Parameters:
    - filtered: The array containing NaN values.
    - unfiltered: The original array with all valid values.

    Returns:
    - A new array where NaNs and their neighbors are replaced with values from the unfiltered array.
    """
    if filtered.shape != unfiltered.shape:
        raise ValueError("Filtered and unfiltered arrays must have the same shape.")

    result = filtered.copy()
    nan_indices = np.where(np.isnan(filtered))[0]
    indices_to_replace = set()

    for idx in nan_indices:
        indices_to_replace.add(idx)
        if idx > 0:
            indices_to_replace.add(idx - 1)
        if idx < len(filtered) - 1:
            indices_to_replace.add(idx + 1)

    for idx in indices_to_replace:
        result[idx] = unfiltered[idx]

    return result

# %%
def poly_fit(x_MDS, x_MUS, y_MDS, y_MUS, plot_1=True, plot_2=True, plot_3=True, name=None, upwind=True, Save=True):
    import numpy as np
    import matplotlib.pyplot as plt
    from numpy.polynomial import Polynomial

    mask_MDS = (x_MDS >= -4) & (x_MDS <= 4)
    mask_MUS = (x_MUS >= -4) & (x_MUS <= 4)

    X_MDS = x_MDS[mask_MDS]
    Y_MDS = y_MDS[mask_MDS]
    X_MUS = x_MUS[mask_MUS]
    Y_MUS = y_MUS[mask_MUS]

    deg = 3
    p_MDS = Polynomial.fit(X_MDS, Y_MDS, deg).convert()
    p_MUS = Polynomial.fit(X_MUS, Y_MUS, deg).convert()

    derivative_MDS = p_MDS.deriv()
    derivative_MUS = p_MUS.deriv()

    Y_MDS_fit = p_MDS(X_MDS)
    Y_MUS_fit = p_MUS(X_MUS)

    average = (p_MDS(0) + p_MUS(0)) / 2
    Y_MDS_average = Y_MDS - p_MDS(0) + average
    Y_MUS_average = Y_MUS - p_MUS(0) + average
    Y_MDS_fit_average = Y_MDS_fit - p_MDS(0) + average
    Y_MUS_fit_average = Y_MUS_fit - p_MUS(0) + average

    cl_label = r'$C_{L,1}$' if upwind else r'$C_{L,2}$'
    x_label = r'$\alpha_1$ / $\alpha_2$ [deg]'
    label_MUS = f'{cl_label}($\\alpha_1$, 0)'
    label_MDS = f'{cl_label}(0, $\\alpha_2$)'
    if upwind:
        label_MUS_avg = fr'$\hat{{C}}_{{L,1}}(\alpha_1, 0)$'
        label_MDS_avg = fr'$\hat{{C}}_{{L,1}}(0, \alpha_2)$'
    else:
        label_MUS_avg = fr'$\hat{{C}}_{{L,2}}(\alpha_1, 0)$'
        label_MDS_avg = fr'$\hat{{C}}_{{L,2}}(0, \alpha_2)$'


    if plot_1:
        fig1 = plt.figure(figsize=(4.5, 3.3))
        plt.plot(X_MDS, Y_MDS, label=label_MDS, color='blue', linewidth=0.7, alpha=0.8)
        plt.plot(X_MUS, Y_MUS, label=label_MUS, color='red', linewidth=0.7, alpha=0.8)
        plt.plot(X_MDS, Y_MDS_fit, '--', label=label_MDS + ' Fit', color='blue', linewidth=1)
        plt.plot(X_MUS, Y_MUS_fit, '--', label=label_MUS + ' Fit', color='red', linewidth=1)
        plt.xlabel(x_label, fontsize=14)
        plt.ylabel(cl_label, fontsize=14)
        plt.ylim(-0.48, 0.45)
        #plt.title(name, fontsize=16)
        plt.grid(True, linestyle=':')
        plt.legend(fontsize=12)
        plt.tight_layout()
        if Save and name:
            fig1.savefig(f'{name}_Lift_plot1.png', dpi=300, bbox_inches='tight')
        plt.show()

    if plot_2:
        fig2 = plt.figure(figsize=(4.5, 3.3))
        plt.plot(X_MDS, Y_MDS_average, label=label_MDS_avg, color='blue', linewidth=0.7, alpha=0.8)
        plt.plot(X_MUS, Y_MUS_average, label=label_MUS_avg, color='red', linewidth=0.7, alpha=0.8)
        plt.plot(X_MDS, Y_MDS_fit_average, '--', label=label_MDS_avg + ' Fit', color='blue', linewidth=1)
        plt.plot(X_MUS, Y_MUS_fit_average, '--', label=label_MUS_avg + ' Fit', color='red', linewidth=1)
        plt.xlabel(x_label, fontsize=14)
        plt.ylabel(cl_label, fontsize=14)
        plt.ylim(-0.48, 0.45)
        line1 = name if name else ''
        line2 = r'Aligned at $\alpha_1 = \alpha_2 = 0$'
        #plt.title(f'{line1}\n{line2}', fontsize=15)
        plt.grid(True, linestyle=':')
        plt.legend(fontsize=12)
        plt.tight_layout()
        if Save and name:
            fig2.savefig(f'{name}_Lift_plot2.png', dpi=300, bbox_inches='tight')
        plt.show()

    if plot_3:
        alpha1_vals = np.concatenate([np.zeros_like(X_MDS), X_MUS])
        alpha2_vals = np.concatenate([X_MDS, np.zeros_like(X_MUS)])
        y_vals = np.concatenate([p_MDS(X_MDS), p_MUS(X_MUS)])

        def poly2D_design_matrix(x, y, deg):
            terms = [(i, j) for i in range(deg + 1) for j in range(deg + 1 - i)]
            A = np.vstack([x**i * y**j for i, j in terms]).T
            return A, terms

        A, terms = poly2D_design_matrix(alpha1_vals, alpha2_vals, deg)
        coeffs, *_ = np.linalg.lstsq(A, y_vals, rcond=None)

        grid_x = np.linspace(-4, 4, 100)
        grid_y = np.linspace(-4, 4, 100)
        A1, A2 = np.meshgrid(grid_x, grid_y)
        Z = np.zeros_like(A1)
        for (i, j), c in zip(terms, coeffs):
            Z += c * A1**i * A2**j

        fig3 = plt.figure(figsize=(10, 6))
        ax = fig3.add_subplot(111, projection='3d')
        ax.plot_surface(A1, A2, Z, cmap='coolwarm', alpha=0.95)
        ax.set_xlabel(r'$\alpha_1$ [deg]', fontsize=12)
        ax.set_ylabel(r'$\alpha_2$ [deg]', fontsize=12)
        ax.set_zlabel(cl_label, fontsize=12)
        ax.zaxis.set_label_coords(-0.05, 0.5)
        line1 = name if name else ''
        line2 = r'2D polynomial surface fit from $\alpha_1$ and $\alpha_2$ data'
        #ax.set_title(f'{line1}\n{line2}', fontsize=14)
        fig3.subplots_adjust(right=0.85)
        ax.set_box_aspect(aspect=None, zoom=0.85)
        if Save and name:
            fig3.savefig(f'{name}_Lift_plot3.png', dpi=300, bbox_inches='tight')
        plt.show()

    return p_MUS(0), p_MDS(0), average, derivative_MUS(0), derivative_MDS(0)

# %%
def CL(x_MDS, MDS_unfiltered, x_MUS, MUS_unfiltered, MDS_filtered = 0, MUS_filtered = 0, name = '', upwind=True):
    if np.all(MDS_filtered == 0):
        y_MDS = MDS_unfiltered
    else:
        y_MDS = fix(MDS_filtered, MDS_unfiltered)
        #y_MDS = MDS_unfiltered

    if np.all(MUS_filtered == 0):
        y_MUS = MUS_unfiltered
    else:
        y_MUS = fix(MUS_filtered, MUS_unfiltered)
        #y_MUS = MUS_unfiltered

    CL_MUS, CL_MDS, CL_mean, CL_d_MUS, CL_d_MDS = poly_fit(x_MDS, x_MUS, y_MDS, y_MUS, plot_1=True, plot_2=True, plot_3=False, name=name, upwind=upwind)

    filename = name + '.npy'
    save_dir = 'Static_coeff_for_buffeting'

    save_path = os.path.join(save_dir, filename)

    os.makedirs(save_dir, exist_ok=True)

    np.save(save_path, np.array([CL_mean, CL_d_MUS, CL_d_MDS]))

    print(f"Numpy array saved to {save_path}")

    print(CL_MUS, CL_MDS, CL_mean, CL_d_MUS, CL_d_MDS)

# %%
# CL(cl_alpha_1D_mds_high, cl_1D_mds_high_upwind_deck,
#    cl_alpha_1D_mus_high, cl_1D_mus_high_upwind_deck,
#    MDS_filtered=cl_1D_mds_high_upwind_deck_filtered, MUS_filtered=cl_1D_mus_high_upwind_deck_filtered,
#    name='CL_Upwind_1D', upwind=True)

# CL(cl_alpha_1D_mds_high, cl_1D_mds_high_downwind_deck,
#    cl_alpha_1D_mus_high, cl_1D_mus_high_downwind_deck,
#    MDS_filtered=cl_1D_mds_high_downwind_deck_filtered, MUS_filtered=cl_1D_mus_high_downwind_deck_filtered,
#    name='CL_Downwind_1D', upwind=False)

# CL(cl_alpha_2D_mds_high, cl_2D_mds_high_upwind_deck,
#    cl_alpha_2D_mus_high, cl_2D_mus_high_upwind_deck,
#    MDS_filtered=0, MUS_filtered=cl_2D_mus_high_upwind_deck_filtered,
#    name='CL_Upwind_2D', upwind=True)

# CL(cl_alpha_2D_mds_high, cl_2D_mds_high_downwind_deck,
#    cl_alpha_2D_mus_high, cl_2D_mus_high_downwind_deck,
#    MDS_filtered=0, MUS_filtered=cl_2D_mus_high_downwind_deck_filtered,
#    name='CL_Downwind_2D', upwind=False)

CL(cl_alpha_3D_mds_high, cl_3D_mds_high_upwind_deck,
   cl_alpha_3D_mus_high, cl_3D_mus_high_upwind_deck,
   MDS_filtered=0, MUS_filtered=cl_3D_mus_high_upwind_deck_filtered,
   name='CL_Upwind_3D', upwind=True)

# CL(cl_alpha_3D_mds_high, cl_3D_mds_high_downwind_deck,
#    cl_alpha_3D_mus_high, cl_3D_mus_high_downwind_deck,
#    MDS_filtered=0, MUS_filtered=cl_3D_mus_high_downwind_deck_filtered,
#    name='CL_Downwind_3D', upwind=False)

# CL(cl_alpha_4D_mds_high, cl_4D_mds_high_upwind_deck,
#    cl_alpha_4D_mus_high, cl_4D_mus_high_upwind_deck,
#    MDS_filtered=0, MUS_filtered=cl_4D_mus_high_upwind_deck_filtered,
#    name='CL_Upwind_4D', upwind=True)

# CL(cl_alpha_4D_mds_high, cl_4D_mds_high_downwind_deck,
#    cl_alpha_4D_mus_high, cl_4D_mus_high_downwind_deck,
#    MDS_filtered=0, MUS_filtered=cl_4D_mus_high_downwind_deck_filtered,
#    name='CL_Downwind_4D', upwind=False)

# CL(cl_alpha_5D_mds_high, cl_5D_mds_high_upwind_deck,
#    cl_alpha_5D_mus_high, cl_5D_mus_high_upwind_deck,
#    MDS_filtered=0, MUS_filtered=cl_5D_mus_high_upwind_deck_filtered,
#    name='CL_Upwind_5D', upwind=True)

# CL(cl_alpha_5D_mds_high, cl_5D_mds_high_downwind_deck,
#    cl_alpha_5D_mus_high, cl_5D_mus_high_downwind_deck,
#    MDS_filtered=0, MUS_filtered=cl_5D_mus_high_downwind_deck_filtered,
#    name='CL_Downwind_5D', upwind=False)
# Out:
# Numpy array saved to Static_coeff_for_buffeting\CL_Upwind_3D.npy
# 0.03163704531420272 0.07020399317443299 0.050920519244317855 0.08089630663813367 0.019920368720528058

# %%
CL(cl_alpha_single_high, cl_single_high,  cl_alpha_single_high, cl_single_high, MDS_filtered = cl_single_high_filtered, MUS_filtered = cl_single_high_filtered, name = 'CL_Single')
# Out:
# Numpy array saved to Static_coeff_for_buffeting\CL_Single.npy
# -0.0012315973701501669 -0.0012315973701501669 -0.0012315973701501669 0.09109965937278666 0.09109965937278666
